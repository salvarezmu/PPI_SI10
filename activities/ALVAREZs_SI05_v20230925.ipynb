# %% [markdown]
# ## «*Olvidaba que en todo combate entre el fanatismo y el sentido común, pocas veces logra este último imponerse*».
# ### [Marguerite Yourcenar](https://es.wikipedia.org/wiki/Marguerite_Yourcenar)

# %% [markdown]
# # ppi_SI_05_NumPy
#
# Actividad individual.
#
# Utilice el dataset seleccionado en **SI01 Repositorio csv de Kaggle**.
#
# Diligencie las casillas indicadas siguiendo las normas de estilo del PEP8.

# %% [markdown]
# # Preparación del ejercicio
#
# *   Importe las librerías requeridas
# *   Lea el dataset a utilizar desde una url
#
# Sugerencia: suba el dataset a Googledrive y luego publíquelo como página web. El siguiente enlace le indica cómo hacerlo: [Cómo publicar archivos de Documentos, Hojas de cálculo, Presentaciones y Formularios de Google](https://support.google.com/docs/answer/183965?hl=es-419&co=GENIE.Platform%3DDesktop).
#
# Nota: si lo desea puede utilizar otro método para obtener la url del dataset.

# %%
# Importar las librerías necesarias
import numpy as np

# Conocer la versiones de las librerías instaladas
print(f"La versión instalada de NumPy es: {np.__version__}\n")

# Guardar en la variable 'ruta' la url del dataset
ruta = ('https://docs.google.com/spreadsheets/d/e/'
        '2PACX-1vTFw_DicCY7BH56cQPE3rQEMjj88R8cqMADrC6rwJ'
        'UeWxVN6o2CDYfTsJtzd9768BA8KXNIC6MIEb-M/pub'
        '?gid=1816493422&single=true&output=csv')

# Cargar el dataset a partir de la ruta establecida
raw_dataset = np.loadtxt(ruta, delimiter=',', dtype=str, quotechar='"')
pokemon_dataset = np.array(raw_dataset[1:])

# Verificar la lectura del dataset
print(pokemon_dataset)
# Out:
# La versión instalada de NumPy es: 1.23.5
#
# [['1' '1' '"Bulbasaur"' ... '20' 'NULL' 'NULL']
#  ['2' '2' '"Ivysaur"' ... '20' '1' '"Level 16"']
#  ['3' '3' '"Venusaur"' ... '20' '2' '"Level 32"']
#  ...
#  ['1749' '1006' '"Iron Valiant"' ... '50' 'NULL' 'NULL']
#  ['1647' '1007' '"Koraidon"' ... '0' 'NULL' 'NULL']
#  ['1648' '1008' '"Miraidon"' ... '0' 'NULL' 'NULL']]

# %% [markdown]
# # Explorar el dataset
#
# Muestre las principales características del dataset.

# %%
import numpy as np

# Se imprime la forma del areglo
print(f"La forma del pokemon_dataset es: {pokemon_dataset.shape}\n")

# Se imprime la dimensión del arreglo
print(f"La dimensión del pokemon_dataset es: {pokemon_dataset.ndim}\n")

# Se imprime las filas del arreglo
print(f"La cantidad de filas del pokemon_dataset \
es: {pokemon_dataset.shape[0]}\n")

# Se imprime las columnas del arreglo
print(f"La cantidad de columnas del pokemon_dataset \
es: {pokemon_dataset.shape[1]}\n")
# Out:
# La forma del pokemon_dataset es: (1235, 45)
#
# La dimensión del pokemon_dataset es: 2
#
# La cantidad de filas del pokemon_dataset es: 1235
#
# La cantidad de columnas del pokemon_dataset es: 45

# %% [markdown]
# # Transformar el dataset

# %% [markdown]
# ## arreglo_00
#
# Cree el arreglo_00 con las siguientes características:
#
# *  seis columnas (dentro de las seis columnas deben estar la primera y la última columna del dataset original)
# *  veinte filas (las filas deben corresponder a las diez primeras filas y las diez últimas filas del dataset original)
#
# Muestre el resultado y las características del arreglo.

# %%
import numpy as np

# Se seleccionan las primeras 10 filas del dataset
first_rows = np.hstack((pokemon_dataset[:10, :3], pokemon_dataset[:10, -3:]))

# Se seleccionan las últimas 10 filas del dataset
last_rows = np.hstack((pokemon_dataset[-10:, :3], pokemon_dataset[-10:, -3:]))

# Crear el arreglo_00 con las características específicadas
arreglo_00 = np.vstack((first_rows, last_rows))

# Se imprime el arreglo
print(arreglo_00)

# %% [markdown]
# ## arreglo_01
#
# Cree el arreglo_01 (diez columnas y doce filas) a partir del arreglo_00.
#
# Muestre el resultado y las características del arreglo.

# %%
import numpy as np

# Se crea una copia del arreglo_00 para no modificar el original
arreglo_01 = arreglo_00.copy()

# Se modifica la forma del arreglo para ajustarse a los requerimientos
arreglo_01.shape = (12, 10)

# Se imprime la forma del areglo
print(f"La forma del arreglo_01 es: {arreglo_01.shape}\n")

# Se imprime las filas y columnas del arreglo
print(f"El arreglo_01 tiene: {arreglo_01.shape[0]} \
filas  y {arreglo_01.shape[1]} columnas\n")

# Se imprime el arreglo
print(arreglo_01, '\n')

# %% [markdown]
# ## arreglo_02
#
# Cree el arreglo_02 (cinco columnas y diez filas) a partir del dataset original. Todos los datos deben ser números.
#
# Agregue al arreglo_02 lo siguiente:
#
# * una columna con todos los valores iguales a cinco
# * una columna con todos los valores iguales a uno
# * una columna con números aleatorios provenientes de una distribución normal de media 0 y desviación típica 1
# * una columna con números aleatorios enteros en el intervalo 200 a 300
# * una columna con números aleatorios binarios (0,1)
#
# Muestre el resultado y las características del arreglo.

# %%
import numpy as np

# Se genera un arreglo con todos los valores iguales a 5
only_five_numbers = np.full(10, 5)

# Se genera un arreglo con todos los números iguales a 1
only_one_numbers = np.ones(10, dtype=int)

# Se genera un arreglo con números aleatorios de una distribucion normal
normal_distribution = np.random.normal(0, 1, 10)

# Se genera un arreglo con números aleatorios entre 200 y 300
random_numbers = np.random.randint(200, 300, 10)

# Se genera un arreglo con números aleatorios binarios
binary_random_numbers = np.random.randint(2, size=10)

# Se crea el arreglo a partir del dataset original y las columnas adicionales
# Las características seleccionadas son:
# Id, Health Stat, Attack Stat, Defense Stat, Special Attack Stat
arreglo_02 = np.vstack((
    pokemon_dataset[:10, 0],
    pokemon_dataset[:10, 23],
    pokemon_dataset[:10, 24],
    pokemon_dataset[:10, 25],
    pokemon_dataset[:10, 26],
    only_five_numbers,
    only_one_numbers,
    normal_distribution,
    random_numbers,
    binary_random_numbers
    )).T

# Se imprime la forma del areglo
print(f"La forma del arreglo_02 es: {arreglo_02.shape}\n")

# Se imprime las filas y columnas del arreglo
print(f"El arreglo_02 tiene: {arreglo_02.shape[0]} \
filas  y {arreglo_02.shape[1]} columnas\n")


# Se imprime el arreglo
print(arreglo_02, "\n")

# %% [markdown]
# # Operaciones con dataset

# %% [markdown]
# ## arreglo_03
#
# Cree el arreglo_03 como la matriz transpuesta del arreglo_02 obtenido en el ejercicio anterior.
#
# Encuentre la inversa del arreglo_03 y multiplíquela por el arreglo_03.
#
# Muestre los arreglos obtenidos y las características de cada uno de ellos.

# %%
import numpy as np

# Se crea el arreglo_03 como la traspuesta del arreglo_02
arreglo_03 = np.round(arreglo_02.copy().T.astype(np.float64), 2)

print(f"El arreglo_03 tiene: {arreglo_03.shape[0]} \
filas  y {arreglo_03.shape[1]} columnas.\nEl arreglo_03 es: \n")
print(arreglo_03, "\n")


# Se crea el la matriz inversa del arreglo_03
arreglo_03_inv = np.linalg.inv(arreglo_03)

print(f"La matriz inversa del arreglo_03 tiene: {arreglo_03.shape[0]} \
filas  y {arreglo_03.shape[1]} columnas.\n\
La matriz inversa del arreglo_03: \n")
print(arreglo_03_inv, "\n")

# Se multiplica el arreglo_03 y su matriz inversa
multiplied_arrays = arreglo_03 * arreglo_03_inv

print(f"La multiplicación de las matrices tiene: {arreglo_03.shape[0]} \
filas  y {arreglo_03.shape[1]} columnas.\n\
La multiplicación de las matrices: \n")
print(multiplied_arrays, "\n")

# %% [markdown]
# ## arreglo_04
#
# Cree el arreglo_04 como la suma del arreglo_03 con su transpuesta.
#
# Muestre el resultado y las características del arreglo.

# %%
# Se crea el arreglo_04 a partir del arreglo_03 y su traspuesta
arreglo_04 = arreglo_03 + arreglo_03.T

# Se imprime la forma del areglo
print(f"La forma del arreglo_04 es: {arreglo_04.shape}\n")

# Se imprime las filas y columnas del arreglo
print(f"El arreglo_04 tiene: {arreglo_04.shape[0]} \
filas  y {arreglo_04.shape[1]} columnas\n")

# Se imprime el arreglo
print(arreglo_04, "\n")

# %% [markdown]
# ## arreglo_05
#
# Cree el arreglo_05 a partir del arreglo_04 reemplazando los valores inferiores o iguales a la media por cero, y los valores superiores a la media por cinco.
#
# Muestre el resultado y las características del arreglo.

# %%
import numpy as np

# Se crea una copia del arreglo_04 para no modificarlo
arreglo_05 = arreglo_04.copy()

# Se calcula la media del arreglo
mean = np.mean(arreglo_05)

# Se reemplazan los valores por los requeridos
arreglo_05[arreglo_05 <= mean] = 0
arreglo_05[arreglo_05 > mean] = 5

# Se imprimen los valores obtenidos
print("El arreglo_05 es: \n")
print(arreglo_05.astype(int))

# %% [markdown]
# ## arreglo_06
#
# Cree el arreglo_06 **juntando de forma horizontal** el arreglo_03 y el arreglo_04.
#
# Muestre el resultado y las características del arreglo.

# %%
import numpy as np

# Se crea el arreglo
arreglo_06 = np.hstack((arreglo_03, arreglo_04))

# Se imprime la forma del areglo
print(f"La forma del arreglo_06 es: {arreglo_06.shape}\n")

# Se imprime las filas y columnas del arreglo
print(f"El arreglo_06 tiene: {arreglo_06.shape[0]} \
filas  y {arreglo_06.shape[1]} columnas\n")

print(arreglo_06, "\n")

# %% [markdown]
# ## arreglo_07
#
# Cree el arreglo_07 **juntando de forma vertical** el arreglo_03 y el arreglo_04

# %%
import numpy as np

# Se crea el arreglo
arreglo_07 = np.vstack((arreglo_03, arreglo_04))

# Se imprime la forma del areglo
print(f"La forma del arreglo_07 es: {arreglo_07.shape}\n")

# Se imprime las filas y columnas del arreglo
print(f"El arreglo_07 tiene: {arreglo_07.shape[0]} \
filas  y {arreglo_07.shape[1]} columnas\n")

print(arreglo_07, "\n")
